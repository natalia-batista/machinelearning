# %%
import tensorflow as tf
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000] #cortando o train set até os 5000 últimos elementos
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]

X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255. #ajustando a escala para 0-1 e convertendo para floats

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
tf.random.set_seed(42)
tf.keras.backend.clear_session()

# %%
normalization_layer = tf.keras.layers.Normalization() #scales up the features
hidden_layer1 = tf.keras.layers.Dense(30,activation = 'relu')
hidden_layer2 = tf.keras.layers.Dense(30, activation = 'relu')
concat_layer = tf.keras.layers.Concatenate()
output_layer = tf.keras.layers.Dense(1)

input_ = tf.keras.layers.Input(shape = X_train.shape[1:])
hidden1 = hidden_layer1(input_)
hidden2 = hidden_layer2(hidden1)
concat = concat_layer([input_,hidden2]) # une os caminhos wide and deep
output = output_layer(concat)

model = tf.keras.Model(inputs=[input_], outputs=[output])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=3.3e-4)
model.compile(loss='mse',optimizer=optimizer, metrics=['RootMeanSquaredError'])
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 6s 3ms/step - loss: 8.2423 - root_mean_squared_error: 2.8710 - val_loss: 8.3711 - val_root_mean_squared_error: 2.8935
# Epoch 2/20
# 1719/1719 [==============================] - 6s 3ms/step - loss: 8.2395 - root_mean_squared_error: 2.8705 - val_loss: 8.3695 - val_root_mean_squared_error: 2.8932
# Epoch 3/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2409 - root_mean_squared_error: 2.8707 - val_loss: 8.3757 - val_root_mean_squared_error: 2.8942
# Epoch 4/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2399 - root_mean_squared_error: 2.8705 - val_loss: 8.3668 - val_root_mean_squared_error: 2.8927
# Epoch 5/20
# 1719/1719 [==============================] - 6s 3ms/step - loss: 8.2397 - root_mean_squared_error: 2.8705 - val_loss: 8.3696 - val_root_mean_squared_error: 2.8932
# Epoch 6/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2397 - root_mean_squared_error: 2.8705 - val_loss: 8.3691 - val_root_mean_squared_error: 2.8931
# Epoch 7/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2395 - root_mean_squared_error: 2.8704 - val_loss: 8.3687 - val_root_mean_squared_error: 2.8931
# Epoch 8/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2396 - root_mean_squared_error: 2.8705 - val_loss: 8.3730 - val_root_mean_squared_error: 2.8938
# Epoch 9/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2406 - root_mean_squared_error: 2.8706 - val_loss: 8.3703 - val_root_mean_squared_error: 2.8933
# Epoch 10/20
# 1719/1719 [==============================] - 6s 3ms/step - loss: 8.2402 - root_mean_squared_error: 2.8706 - val_loss: 8.3705 - val_root_mean_squared_error: 2.8933
# Epoch 11/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2408 - root_mean_squared_error: 2.8706 - val_loss: 8.3688 - val_root_mean_squared_error: 2.8931
# Epoch 12/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2398 - root_mean_squared_error: 2.8705 - val_loss: 8.3846 - val_root_mean_squared_error: 2.8958
# Epoch 13/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2406 - root_mean_squared_error: 2.8707 - val_loss: 8.3791 - val_root_mean_squared_error: 2.8948
# Epoch 14/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2392 - root_mean_squared_error: 2.8704 - val_loss: 8.3670 - val_root_mean_squared_error: 2.8928
# Epoch 15/20
# 1719/1719 [==============================] - 6s 3ms/step - loss: 8.2402 - root_mean_squared_error: 2.8706 - val_loss: 8.3667 - val_root_mean_squared_error: 2.8927
# Epoch 16/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2401 - root_mean_squared_error: 2.8706 - val_loss: 8.3683 - val_root_mean_squared_error: 2.8930
# Epoch 17/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2398 - root_mean_squared_error: 2.8705 - val_loss: 8.3741 - val_root_mean_squared_error: 2.8940
# Epoch 18/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2400 - root_mean_squared_error: 2.8705 - val_loss: 8.3660 - val_root_mean_squared_error: 2.8926
# Epoch 19/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 8.2400 - root_mean_squared_error: 2.8706 - val_loss: 8.3715 - val_root_mean_squared_error: 2.8935
# Epoch 20/20
# 1719/1719 [==============================] - 6s 3ms/step - loss: 8.2409 - root_mean_squared_error: 2.8707 - val_loss: 8.3663 - val_root_mean_squared_error: 2.8926
